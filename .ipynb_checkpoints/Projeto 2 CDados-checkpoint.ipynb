# %%
# %matplotlib notebook
#Importando bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, probplot
import statsmodels.api as sm
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display

# %%
#Carregando o dataset principal (target) sobre a produção de carne
target_carne_produzida = pd.read_csv('meat-production-tonnes.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado e separar apenas os dados de 2010
pais_carne_produzida = target_carne_produzida['Entity']    
producao_2010 = target_carne_produzida['Year'] == 2010
target_carne_produzida = target_carne_produzida.loc[producao_2010, :]
target_carne_produzida = target_carne_produzida.rename(columns={'Entity' : 'Country'})
target_carne_produzida = target_carne_produzida.rename(columns={'Livestock Primary - Meat, Total - 1765 - Production - 5510 - tonnes (tonnes)' : 'Meat Tonnes'})

# %%
#Carregando um dataset de feature sobre o consumo de carne
feature_consumo_per_capita = pd.read_csv('per-capita-meat-consumption-by-type-kilograms-per-year.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado e separar apenas os dados de 2010
producao_2010 = feature_consumo_per_capita['Year'] == 2010
consumo_2010_per_cpt = feature_consumo_per_capita.loc[producao_2010, :]
consumo_2010_per_cpt = consumo_2010_per_cpt.loc[:, ['Entity', 'Year', 'Beef and bufallo (kilograms per year)']]
consumo_2010_per_cpt = consumo_2010_per_cpt.rename(columns={'Entity' : 'Country'})
pais_consumo_2010_per_cpt = consumo_2010_per_cpt['Country']

# %%
#Carregando um dataset de features importantes (IDH, Expect. de vida, etc...)
feature_IDH = pd.read_csv('HDI.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado
IDH_dados_importantes = feature_IDH.loc[:,['Country', 'HDI', 'Life expectancy', 'Mean years of schooling', 'Coefficient of human inequality']]
pais_IDH = IDH_dados_importantes['Country']

# %%
#Carregando um dataset de feature sobre o desemprego 
feature_desemprego_pais = pd.read_csv('API_ILO_country_YU.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado e separar apenas os dados de 2010
desemprego_2010 = feature_desemprego_pais.loc[:,['Country Name', '2010']]
desemprego_2010 = desemprego_2010.rename(columns={'Country Name' : 'Country'})
desemprego_2010 = desemprego_2010.rename(columns={'2010' : 'Desemprego em 2010'})

# %%
#Carregando um dataset de feature sobre o PIB
feature_pib = pd.read_csv('GDP.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado e separar apenas os dados de 2010
pib_2010 = feature_pib.loc[:,['Country ', '2010']]
pib_2010 = pib_2010.rename(columns={'2010' : 'PIB em 2010'})

# %%
feature_dados_commodity = pd.read_csv('commodity_trade_statistics_data.csv') 
ano_2010 = feature_dados_commodity['year'] == 2010
commodity_2010 = feature_dados_commodity.loc[ano_2010, :]
commodity_2010 = commodity_2010.loc[:, ['country_or_area', 'year', 'commodity', 'flow', 'trade_usd', 'weight_kg', 'category']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-8347af0462d2> in <module>
# ----> 1 feature_dados_commodity = pd.read_csv('commodity_trade_statistics_data.csv')
#       2 ano_2010 = feature_dados_commodity['year'] == 2010
#       3 commodity_2010 = feature_dados_commodity.loc[ano_2010, :]
#       4 commodity_2010 = commodity_2010.loc[:, ['country_or_area', 'year', 'commodity', 'flow', 'trade_usd', 'weight_kg', 'category']]
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'commodity_trade_statistics_data.csv'

# %% [markdown]
# ## Agora, iremos juntar todos os datasets anteriores em um único para fazermos as regressões e análises

# %%
#Juntando todos os datasets em um único, tendo como base (index principal) o país
tabela_1 = target_carne_produzida.set_index('Country').join(consumo_2010_per_cpt.set_index('Country'), lsuffix='_carne', rsuffix='_consumo')
tabela_2 = tabela_1.join(IDH_dados_importantes.set_index('Country'), lsuffix='_carne', rsuffix='_consumo')
tabela_3 = tabela_2.join(desemprego_2010.set_index('Country'), lsuffix='_carne', rsuffix='_consumo' )
tabela_final = tabela_3.join(pib_2010.set_index('Country '), lsuffix='_carne', rsuffix='_consumo')

# %%
#Retirando os países que apresentarem 'NaN' e removendo algumas colunas para deixar mais organizado e melhor para ser analisado
tabela_final = tabela_final.dropna()
tabela_final = tabela_final.drop(columns=['Code', 'Year_consumo', 'Year_carne'])
tabela_final
# Out:
#                Meat Tonnes  Beef and bufallo (kilograms per year)    HDI  \
# Country
# Afghanistan         328160                                   4.70  0.479
# Albania              91440                                  21.38  0.764
# Angola              217027                                   6.67  0.533
# Argentina          4721922                                  54.65  0.827
# Armenia              69484                                  18.01  0.743
# ...                    ...                                    ...    ...
# United States     41952752                                  38.66  0.920
# Uruguay             652983                                  30.76  0.795
# Uzbekistan          818300                                  23.98  0.701
# Zambia              265615                                   5.64  0.579
# Zimbabwe            255822                                   7.65  0.516
#
#                Life expectancy  Mean years of schooling  \
# Country
# Afghanistan               60.7                      3.6
# Albania                   78.0                      9.6
# Angola                    52.7                      5.0
# Argentina                 76.5                      9.9
# Armenia                   74.9                     11.3
# ...                        ...                      ...
# United States             79.2                     13.2
# Uruguay                   77.4                      8.6
# Uzbekistan                69.4                     12.0
# Zambia                    60.8                      6.9
# Zimbabwe                  59.2                      7.7
#
#                Coefficient of human inequality  Desemprego em 2010  \
# Country
# Afghanistan                               30.4           20.600000
# Albania                                   13.4           25.799999
# Angola                                    36.6           10.800000
# Argentina                                 15.2           19.500000
# Armenia                                    9.2           38.299999
# ...                                        ...                 ...
# United States                             12.9           18.700001
# Uruguay                                   15.4           20.799999
# Uzbekistan                                15.3           20.600000
# Zambia                                    34.7           26.400000
# Zimbabwe                                  28.1            9.600000
#
#                 PIB em 2010
# Country
# Afghanistan     1637.377987
# Albania         9628.025783
# Angola          6230.297028
# Argentina      18524.856760
# Armenia         6565.678660
# ...                     ...
# United States  48466.823380
# Uruguay        16808.284880
# Uzbekistan      5136.234068
# Zambia          3269.794329
# Zimbabwe        1888.566739
#
# [121 rows x 8 columns]

# %%
#Renomeando todas as colunas para deixar em português e com algumas unidades utilizadas
tabela_final = tabela_final.rename(columns={'Beef and bufallo (kilograms per year)' : 'Carne consumida/capita (kg/ano)'})
tabela_final = tabela_final.rename(columns={'HDI' : 'IDH'})
tabela_final = tabela_final.rename(columns={'Meat Tonnes' : 'Carne produzida (toneladas/ano)'})
tabela_final = tabela_final.rename(columns={'Life expectancy' : 'Expectativa de vida (anos)'})
tabela_final = tabela_final.rename(columns={'Mean years of schooling' : 'Média de escolaridade (anos)'})
tabela_final = tabela_final.rename(columns={'Coefficient of human inequality' : 'Coeficiente de desigualdade humana'})
tabela_final = tabela_final.rename(columns={'Desemprego em 2010' : 'Taxa de desemprego (%)'})
tabela_final = tabela_final.rename(columns={'PIB em 2010' : 'PIB per capita (U$)'})

# %%
tabela_final.tail(50)
# Out:
#                      Carne produzida (toneladas/ano)  \
# Country
# Mali                                          348425
# Malta                                          15499
# Mauritania                                    100095
# Mauritius                                      50678
# Mexico                                       5828422
# Mongolia                                      204846
# Montenegro                                     11077
# Morocco                                      1032836
# Mozambique                                    167877
# Namibia                                        77314
# Nepal                                         298723
# Netherlands                                  2553316
# Nicaragua                                     233543
# Niger                                         158648
# Nigeria                                      1399115
# Norway                                        341446
# Pakistan                                     2653910
# Panama                                        234683
# Paraguay                                      546254
# Peru                                         1386111
# Philippines                                  2906247
# Poland                                       3583600
# Portugal                                      839128
# Romania                                      1016227
# Rwanda                                         84581
# Senegal                                       166703
# Serbia                                        473741
# Sierra Leone                                   40295
# Slovenia                                      143044
# Solomon Islands                                 3388
# South Africa                                 2783507
# Spain                                        5443530
# Sri Lanka                                     138679
# Suriname                                       15810
# Sweden                                        539415
# Switzerland                                   471671
# Tajikistan                                     73206
# Thailand                                     2396252
# Togo                                           64531
# Trinidad and Tobago                            70116
# Tunisia                                       285819
# Turkey                                       2377559
# Uganda                                        424978
# Ukraine                                      2085539
# United Kingdom                               3533313
# United States                               41952752
# Uruguay                                       652983
# Uzbekistan                                    818300
# Zambia                                        265615
# Zimbabwe                                      255822
#
#                      Carne consumida/capita (kg/ano)    IDH  \
# Country
# Mali                                            9.94  0.442
# Malta                                          17.24  0.856
# Mauritania                                      6.69  0.513
# Mauritius                                       5.85  0.781
# Mexico                                         16.30  0.762
# Mongolia                                       16.23  0.735
# Montenegro                                     13.05  0.807
# Morocco                                         6.27  0.647
# Mozambique                                      1.16  0.418
# Namibia                                         9.59  0.640
# Nepal                                           7.90  0.558
# Netherlands                                    18.98  0.924
# Nicaragua                                       5.13  0.645
# Niger                                           8.49  0.353
# Nigeria                                         2.04  0.527
# Norway                                         18.67  0.949
# Pakistan                                        8.45  0.550
# Panama                                         19.91  0.788
# Paraguay                                       11.67  0.693
# Peru                                            4.22  0.740
# Philippines                                     4.57  0.682
# Poland                                          2.76  0.855
# Portugal                                       17.22  0.843
# Romania                                         7.35  0.802
# Rwanda                                          2.54  0.498
# Senegal                                         5.25  0.494
# Serbia                                          9.50  0.776
# Sierra Leone                                    1.59  0.420
# Slovenia                                       19.91  0.890
# Solomon Islands                                 4.01  0.515
# South Africa                                   16.29  0.666
# Spain                                          13.68  0.884
# Sri Lanka                                       1.61  0.766
# Suriname                                       11.66  0.725
# Sweden                                         23.79  0.913
# Switzerland                                    21.48  0.939
# Tajikistan                                      3.86  0.627
# Thailand                                        3.07  0.740
# Togo                                            1.52  0.487
# Trinidad and Tobago                             5.77  0.780
# Tunisia                                         5.65  0.725
# Turkey                                          9.30  0.767
# Uganda                                          5.30  0.493
# Ukraine                                         9.01  0.743
# United Kingdom                                 19.43  0.909
# United States                                  38.66  0.920
# Uruguay                                        30.76  0.795
# Uzbekistan                                     23.98  0.701
# Zambia                                          5.64  0.579
# Zimbabwe                                        7.65  0.516
#
#                      Expectativa de vida (anos)  Média de escolaridade (anos)  \
# Country
# Mali                                       58.5                           2.3
# Malta                                      80.7                          11.3
# Mauritania                                 63.2                           4.3
# Mauritius                                  74.6                           9.1
# Mexico                                     77.0                           8.6
# Mongolia                                   69.8                           9.8
# Montenegro                                 76.4                          11.3
# Morocco                                    74.3                           5.0
# Mozambique                                 55.5                           3.5
# Namibia                                    65.1                           6.7
# Nepal                                      70.0                           4.1
# Netherlands                                81.7                          11.9
# Nicaragua                                  75.2                           6.5
# Niger                                      61.9                           1.7
# Nigeria                                    53.1                           6.0
# Norway                                     81.7                          12.7
# Pakistan                                   66.4                           5.1
# Panama                                     77.8                           9.9
# Paraguay                                   73.0                           8.1
# Peru                                       74.8                           9.0
# Philippines                                68.3                           9.3
# Poland                                     77.6                          11.9
# Portugal                                   81.2                           8.9
# Romania                                    74.8                          10.8
# Rwanda                                     64.7                           3.8
# Senegal                                    66.9                           2.8
# Serbia                                     75.0                          10.8
# Sierra Leone                               51.3                           3.3
# Slovenia                                   80.6                          12.1
# Solomon Islands                            68.1                           5.3
# South Africa                               57.7                          10.3
# Spain                                      82.8                           9.8
# Sri Lanka                                  75.0                          10.9
# Suriname                                   71.3                           8.3
# Sweden                                     82.3                          12.3
# Switzerland                                83.1                          13.4
# Tajikistan                                 69.6                          10.4
# Thailand                                   74.6                           7.9
# Togo                                       60.2                           4.7
# Trinidad and Tobago                        70.5                          10.9
# Tunisia                                    75.0                           7.1
# Turkey                                     75.5                           7.9
# Uganda                                     59.2                           5.7
# Ukraine                                    71.1                          11.3
# United Kingdom                             80.8                          13.3
# United States                              79.2                          13.2
# Uruguay                                    77.4                           8.6
# Uzbekistan                                 69.4                          12.0
# Zambia                                     60.8                           6.9
# Zimbabwe                                   59.2                           7.7
#
#                      Coeficiente de desigualdade humana  \
# Country
# Mali                                               32.7
# Malta                                               8.0
# Mauritania                                         31.9
# Mauritius                                          14.3
# Mexico                                             22.4
# Mongolia                                           13.0
# Montenegro                                          8.7
# Morocco                                            28.3
# Mozambique                                         32.9
# Namibia                                            33.4
# Nepal                                              25.8
# Netherlands                                         6.8
# Nicaragua                                          25.4
# Niger                                              27.5
# Nigeria                                            37.5
# Norway                                              5.4
# Pakistan                                           29.6
# Panama                                             21.0
# Paraguay                                           23.5
# Peru                                               21.3
# Philippines                                        18.2
# Poland                                              9.3
# Portugal                                           10.1
# Romania                                            10.8
# Rwanda                                             31.8
# Senegal                                            32.5
# Serbia                                             11.1
# Sierra Leone                                       36.6
# Slovenia                                            5.8
# Solomon Islands                                    23.8
# South Africa                                       32.0
# Spain                                              10.1
# Sri Lanka                                          11.5
# Suriname                                           23.3
# Sweden                                              6.6
# Switzerland                                         8.4
# Tajikistan                                         14.9
# Thailand                                           20.2
# Togo                                               31.6
# Trinidad and Tobago                                15.0
# Tunisia                                            21.9
# Turkey                                             15.8
# Uganda                                             30.8
# Ukraine                                             7.2
# United Kingdom                                      7.8
# United States                                      12.9
# Uruguay                                            15.4
# Uzbekistan                                         15.3
# Zambia                                             34.7
# Zimbabwe                                           28.1
#
#                      Taxa de desemprego (%)  PIB per capita (U$)
# Country
# Mali                              10.300000          1836.816217
# Malta                             13.200000         27809.106500
# Mauritania                        46.700001          3356.361346
# Mauritius                         23.100000         15612.293420
# Mexico                             9.400000         15260.620550
# Mongolia                          14.100000          7530.753530
# Montenegro                        46.000000         13634.996960
# Morocco                           17.700001          6324.152955
# Mozambique                        40.700001          1010.752656
# Namibia                           44.099998          8500.097148
# Nepal                              4.000000          1946.058721
# Netherlands                        8.800000         45040.318080
# Nicaragua                         12.300000          3887.787537
# Niger                              7.200000           795.682826
# Nigeria                           13.800000          4981.358232
# Norway                             9.200000         57915.019370
# Pakistan                           8.200000          3988.656725
# Panama                            14.900000         15311.029130
# Paraguay                          11.900000          9541.371804
# Peru                               9.000000          9869.070416
# Philippines                       16.799999          5468.305507
# Poland                            23.400000         21048.330520
# Portugal                          22.299999         27259.766100
# Romania                           22.299999         16966.460610
# Rwanda                             0.700000          1383.013387
# Senegal                           13.000000          2718.906572
# Serbia                            45.500000         12797.324270
# Sierra Leone                       5.100000          1183.330094
# Slovenia                          14.600000         27824.648070
# Solomon Islands                    9.100000          1832.831573
# South Africa                      50.799999         11728.160490
# Spain                             42.500000         31680.185390
# Sri Lanka                         18.799999          8328.906620
# Suriname                          20.700001         13841.414920
# Sweden                            25.200001         42179.337120
# Switzerland                        7.700000         53067.724640
# Tajikistan                        17.299999          2094.538959
# Thailand                           4.000000         13213.314740
# Togo                              10.800000          1216.508967
# Trinidad and Tobago               14.000000         30620.174800
# Tunisia                           29.400000         10227.325960
# Turkey                            21.200001         17425.861360
# Uganda                             7.400000          1552.935840
# Ukraine                           17.400000          7664.396582
# United Kingdom                    19.600000         36340.733870
# United States                     18.700001         48466.823380
# Uruguay                           20.799999         16808.284880
# Uzbekistan                        20.600000          5136.234068
# Zambia                            26.400000          3269.794329
# Zimbabwe                           9.600000          1888.566739

# %%
#Criando uma função que sirva para criar as regressões que vamos utilizar para analisar o projeto
def regress(Y,X):
    '''
    Y: coluna do DataFrame utilizada como variável resposta (TARGET)
    X: coluna(s) do DataFrame utilizadas como variável(is) explicativas (FEATURES)
    '''
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    
    return results

# %%
#Criando uma nova variável com o dataset final para facilitar
df = tabela_final[['Carne produzida (toneladas/ano)', 'Carne consumida/capita (kg/ano)',
       'IDH', 'Expectativa de vida (anos)', 'Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)',
       'PIB per capita (U$)']]

# %%
df.describe()
# Out:
#        Carne produzida (toneladas/ano)  Carne consumida/capita (kg/ano)  \
# count                     1.210000e+02                       121.000000
# mean                      1.500236e+06                        11.749174
# std                       4.511072e+06                         9.517539
# min                       8.380000e+02                         0.490000
# 25%                       9.584700e+04                         4.990000
# 50%                       2.858190e+05                         8.490000
# 75%                       9.714000e+05                        17.750000
# max                       4.195275e+07                        54.650000
#
#               IDH  Expectativa de vida (anos)  Média de escolaridade (anos)  \
# count  121.000000                  121.000000                    121.000000
# mean     0.705091                   71.523967                      8.559504
# std      0.162174                    8.735770                      3.253449
# min      0.352000                   50.100000                      1.400000
# 25%      0.563000                   65.100000                      6.100000
# 50%      0.739000                   74.200000                      9.000000
# 75%      0.843000                   78.000000                     11.300000
# max      0.949000                   83.700000                     13.400000
#
#        Coeficiente de desigualdade humana  Taxa de desemprego (%)  \
# count                          121.000000              121.000000
# mean                            19.768595               18.919835
# std                             10.302096               11.503569
# min                              5.300000                0.700000
# 25%                             10.200000               10.300000
# 50%                             18.200000               17.100000
# 75%                             28.600000               25.000000
# max                             43.100000               57.200001
#
#        PIB per capita (U$)
# count           121.000000
# mean          15462.403182
# std           15349.107505
# min             795.682826
# 25%            3269.794329
# 50%           10227.325960
# 75%           21048.330520
# max           85613.586610

# %%
#Separando em 'target' e 'feature' para fazer a regressão
X1 = df[['Carne consumida/capita (kg/ano)',
       'IDH', 'Expectativa de vida (anos)', 'Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)',
       'PIB per capita (U$)']]
Y1 = df['Carne produzida (toneladas/ano)']

# %%
#Fazendo a regressão
results = regress(Y1,X1)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     Carne produzida (toneladas/ano)   R-squared:                       0.221
# Model:                                         OLS   Adj. R-squared:                  0.173
# Method:                              Least Squares   F-statistic:                     4.584
# Date:                             Mon, 29 Nov 2021   Prob (F-statistic):           0.000154
# Time:                                     23:21:28   Log-Likelihood:                -2010.0
# No. Observations:                              121   AIC:                             4036.
# Df Residuals:                                  113   BIC:                             4058.
# Df Model:                                        7
# Covariance Type:                         nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                               -9.24e+06   8.48e+06     -1.089      0.278    -2.6e+07    7.57e+06
# Carne consumida/capita (kg/ano)      1.95e+05   5.04e+04      3.872      0.000    9.52e+04    2.95e+05
# IDH                                 8.821e+06   1.32e+07      0.668      0.506   -1.74e+07     3.5e+07
# Expectativa de vida (anos)         -2.066e+04   1.39e+05     -0.148      0.882   -2.96e+05    2.55e+05
# Média de escolaridade (anos)        7.769e+04   4.26e+05      0.182      0.856   -7.67e+05    9.22e+05
# Coeficiente de desigualdade humana  1.659e+05   9.93e+04      1.671      0.097   -3.08e+04    3.63e+05
# Taxa de desemprego (%)             -1.875e+04   3.66e+04     -0.512      0.610   -9.13e+04    5.38e+04
# PIB per capita (U$)                    7.4968     46.782      0.160      0.873     -85.186     100.180
# ==============================================================================
# Omnibus:                      178.950   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10400.199
# Skew:                           5.680   Prob(JB):                         0.00
# Kurtosis:                      46.975   Cond. No.                     7.83e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.83e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Analisando a expectativa de vida, pois ela é a que apresenta maior P>|t|, para ver se a relação dela com a produção de carne é realmente menos relevante.

# %%
sns.set_theme(color_codes=True)
fig_expect = sns.scatterplot(data=df, x='Expectativa de vida (anos)', y='Carne produzida (toneladas/ano)')
plt.show(fig_expect)
# Out:
# <img src="data:," width="0">

# %%
graf_linha_expec = sns.lineplot(data=df, x='Expectativa de vida (anos)', y='Carne produzida (toneladas/ano)')
plt.show(graf_linha_expec)
# Out:
# <img src="data:," width="0">

# %%
hist_expect = sns.displot(data=df, x='Expectativa de vida (anos)', y='Carne produzida (toneladas/ano)', kind='kde', rug='True')
plt.show(hist_expect)
# Out:
# <img src="data:," width="0">

# %%
fig_reg_expect = sns.regplot(data=df, x='Expectativa de vida (anos)', y='Carne produzida (toneladas/ano)')
plt.show(fig_reg_expect)
# Out:
# <img src="data:," width="0">

# %% [markdown]
# ### Agora, iremos retirar a expectativa de vida do dataset e refazer a regressão para analisar outra feature, que no caso será o PIB per capta (maior P>|t|)

# %%
#Separando em 'target' e 'feature' para fazer a regressão
X2 = df[['Carne consumida/capita (kg/ano)',
       'IDH','Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)',
       'PIB per capita (U$)']]
Y2 = df['Carne produzida (toneladas/ano)']

# %%
#Fazendo a regressão
results = regress(Y2,X2)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     Carne produzida (toneladas/ano)   R-squared:                       0.221
# Model:                                         OLS   Adj. R-squared:                  0.180
# Method:                              Least Squares   F-statistic:                     5.391
# Date:                             Mon, 29 Nov 2021   Prob (F-statistic):           6.19e-05
# Time:                                     23:25:28   Log-Likelihood:                -2010.0
# No. Observations:                              121   AIC:                             4034.
# Df Residuals:                                  114   BIC:                             4054.
# Df Model:                                        6
# Covariance Type:                         nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                              -1.016e+07   5.75e+06     -1.767      0.080   -2.16e+07    1.23e+06
# Carne consumida/capita (kg/ano)     1.946e+05   5.01e+04      3.886      0.000    9.54e+04    2.94e+05
# IDH                                  7.31e+06   8.38e+06      0.872      0.385    -9.3e+06    2.39e+07
# Média de escolaridade (anos)        1.174e+05    3.3e+05      0.356      0.723   -5.37e+05    7.71e+05
# Coeficiente de desigualdade humana  1.724e+05   8.87e+04      1.943      0.054   -3346.386    3.48e+05
# Taxa de desemprego (%)             -1.762e+04   3.57e+04     -0.494      0.622   -8.83e+04     5.3e+04
# PIB per capita (U$)                    9.1136     45.299      0.201      0.841     -80.624      98.851
# ==============================================================================
# Omnibus:                      178.793   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10359.911
# Skew:                           5.673   Prob(JB):                         0.00
# Kurtosis:                      46.888   Cond. No.                     5.67e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.67e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sns.set_theme(color_codes=True)
fig_pib = sns.scatterplot(data=df, x='PIB per capita (U$)', y='Carne produzida (toneladas/ano)')
plt.show(fig_pib)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
graf_linha_pib = sns.lineplot(data=df, x='PIB per capita (U$)', y='Carne produzida (toneladas/ano)')
plt.show(graf_linha_pib)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
hist_pib = sns.displot(data=df, x='PIB per capita (U$)', y='Carne produzida (toneladas/ano)', kind='kde', rug='True')
plt.show(hist_pib)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
fig_reg_pib = sns.regplot(data=df, x='PIB per capita (U$)', y='Carne produzida (toneladas/ano)')
plt.show(fig_reg_pib)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Agora, iremos retirar o PIB per capita do dataset e refazer a regressão para analisar outra feature, que no caso será a média de escolaridade (maior P>|t|)

# %%
#Separando em 'target' e 'feature' para fazer a regressão
X3 = df[['Carne consumida/capita (kg/ano)',
       'IDH','Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)']]
Y3 = df['Carne produzida (toneladas/ano)']

# %%
#Fazendo a regressão
results = regress(Y3,X3)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     Carne produzida (toneladas/ano)   R-squared:                       0.221
# Model:                                         OLS   Adj. R-squared:                  0.187
# Method:                              Least Squares   F-statistic:                     6.515
# Date:                             Mon, 29 Nov 2021   Prob (F-statistic):           2.27e-05
# Time:                                     23:40:50   Log-Likelihood:                -2010.1
# No. Observations:                              121   AIC:                             4032.
# Df Residuals:                                  115   BIC:                             4049.
# Df Model:                                        5
# Covariance Type:                         nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                              -1.052e+07   5.45e+06     -1.929      0.056   -2.13e+07     2.8e+05
# Carne consumida/capita (kg/ano)      1.97e+05   4.85e+04      4.065      0.000    1.01e+05    2.93e+05
# IDH                                 8.065e+06   7.47e+06      1.080      0.282   -6.72e+06    2.29e+07
# Média de escolaridade (anos)        1.131e+05   3.28e+05      0.345      0.731   -5.37e+05    7.63e+05
# Coeficiente de desigualdade humana  1.728e+05   8.84e+04      1.955      0.053   -2268.768    3.48e+05
# Taxa de desemprego (%)             -1.944e+04   3.44e+04     -0.566      0.573   -8.75e+04    4.86e+04
# ==============================================================================
# Omnibus:                      179.465   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10548.064
# Skew:                           5.704   Prob(JB):                         0.00
# Kurtosis:                      47.295   Cond. No.                         756.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.set_theme(color_codes=True)
fig_esc = sns.scatterplot(data=df, x='Média de escolaridade (anos)', y='Carne produzida (toneladas/ano)')
plt.show(fig_esc)
# Out:
# <img src="data:," width="0">

# %%
graf_linha_esc = sns.lineplot(data=df, x='Média de escolaridade (anos)', y='Carne produzida (toneladas/ano)')
plt.show(graf_linha_esc)
# Out:
# <img src="data:," width="0">

# %%
hist_esc = sns.displot(data=df, x='Média de escolaridade (anos)', y='Carne produzida (toneladas/ano)', kind='kde', rug='True')
plt.show(hist_esc)
# Out:
# <img src="data:," width="0">

# %%
fig_reg_esc = sns.regplot(data=df, x='Média de escolaridade (anos)', y='Carne produzida (toneladas/ano)')
plt.show(fig_reg_esc)
# Out:
# <img src="data:," width="0">
