# %% [markdown]
# ***
# # Projeto 2 - Ciência dos Dados
# ***
# ***

# %% [markdown]
# ##### *Alfredo Villela*
# ##### *Leonardo Andrade*
# ##### *Pedro Peretto*
# ***
# # Predição de carne produzida em um determinado país, com base nas suas informações/parâmetros econômicos e sociais.
# ***
# ***

# %%
#Importando bibliotecas necessárias
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import mean_absolute_error
from sklearn import tree

import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

from scipy.stats import norm, probplot

import statsmodels.api as sm

import seaborn as sns

from mpl_toolkits.mplot3d import Axes3D

from IPython.display import display

# %%
#Carregando o dataset principal (target) sobre a produção de carne
target_carne_produzida = pd.read_csv('meat-production-tonnes.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado e separar apenas os dados de 2010
pais_carne_produzida = target_carne_produzida['Entity']    
producao_2010 = target_carne_produzida['Year'] == 2010
target_carne_produzida = target_carne_produzida.loc[producao_2010, :]
target_carne_produzida = target_carne_produzida.rename(columns={'Entity' : 'Country'})
target_carne_produzida = target_carne_produzida.rename(columns={'Livestock Primary - Meat, Total - 1765 - Production - 5510 - tonnes (tonnes)' : 'Meat Tonnes'})

# %%
#Carregando um dataset de feature sobre o consumo de carne
feature_consumo_per_capita = pd.read_csv('per-capita-meat-consumption-by-type-kilograms-per-year.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado e separar apenas os dados de 2010
producao_2010 = feature_consumo_per_capita['Year'] == 2010
consumo_2010_per_cpt = feature_consumo_per_capita.loc[producao_2010, :]
consumo_2010_per_cpt = consumo_2010_per_cpt.loc[:, ['Entity', 'Year', 'Beef and bufallo (kilograms per year)']]
consumo_2010_per_cpt = consumo_2010_per_cpt.rename(columns={'Entity' : 'Country'})
pais_consumo_2010_per_cpt = consumo_2010_per_cpt['Country']

# %%
#Carregando um dataset de features importantes (IDH, Expect. de vida, etc...)
feature_IDH = pd.read_csv('HDI.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado
IDH_dados_importantes = feature_IDH.loc[:,['Country', 'HDI', 'Life expectancy', 'Mean years of schooling', 'Coefficient of human inequality']]
pais_IDH = IDH_dados_importantes['Country']

# %%
#Carregando um dataset de feature sobre o desemprego 
feature_desemprego_pais = pd.read_csv('API_ILO_country_YU.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado e separar apenas os dados de 2010
desemprego_2010 = feature_desemprego_pais.loc[:,['Country Name', '2010']]
desemprego_2010 = desemprego_2010.rename(columns={'Country Name' : 'Country'})
desemprego_2010 = desemprego_2010.rename(columns={'2010' : 'Desemprego em 2010'})

# %%
#Carregando um dataset de feature sobre o PIB
feature_pib = pd.read_csv('GDP.csv')

#Renomeando e criando algumas variáveis do dataset para deixar mais organizado e separar apenas os dados de 2010
pib_2010 = feature_pib.loc[:,['Country ', '2010']]
pib_2010 = pib_2010.rename(columns={'2010' : 'PIB em 2010'})

# %% [markdown]
# ## Agora, iremos juntar todos os datasets anteriores em um único para fazermos as regressões e análises

# %%
#Juntando todos os datasets em um único, tendo como base (index principal) o país
tabela_1 = target_carne_produzida.set_index('Country').join(consumo_2010_per_cpt.set_index('Country'), lsuffix='_carne', rsuffix='_consumo')
tabela_2 = tabela_1.join(IDH_dados_importantes.set_index('Country'), lsuffix='_carne', rsuffix='_consumo')
tabela_3 = tabela_2.join(desemprego_2010.set_index('Country'), lsuffix='_carne', rsuffix='_consumo' )
tabela_final = tabela_3.join(pib_2010.set_index('Country '), lsuffix='_carne', rsuffix='_consumo')

# %%
#Retirando os países que apresentarem 'NaN' e removendo algumas colunas para deixar mais organizado e melhor para ser analisado
tabela_final = tabela_final.dropna()
tabela_final = tabela_final.drop(columns=['Code', 'Year_consumo', 'Year_carne'])
tabela_final
# Out:
#                Meat Tonnes  Beef and bufallo (kilograms per year)    HDI  \
# Country
# Afghanistan         328160                                   4.70  0.479
# Albania              91440                                  21.38  0.764
# Angola              217027                                   6.67  0.533
# Argentina          4721922                                  54.65  0.827
# Armenia              69484                                  18.01  0.743
# ...                    ...                                    ...    ...
# United States     41952752                                  38.66  0.920
# Uruguay             652983                                  30.76  0.795
# Uzbekistan          818300                                  23.98  0.701
# Zambia              265615                                   5.64  0.579
# Zimbabwe            255822                                   7.65  0.516
#
#                Life expectancy  Mean years of schooling  \
# Country
# Afghanistan               60.7                      3.6
# Albania                   78.0                      9.6
# Angola                    52.7                      5.0
# Argentina                 76.5                      9.9
# Armenia                   74.9                     11.3
# ...                        ...                      ...
# United States             79.2                     13.2
# Uruguay                   77.4                      8.6
# Uzbekistan                69.4                     12.0
# Zambia                    60.8                      6.9
# Zimbabwe                  59.2                      7.7
#
#                Coefficient of human inequality  Desemprego em 2010  \
# Country
# Afghanistan                               30.4           20.600000
# Albania                                   13.4           25.799999
# Angola                                    36.6           10.800000
# Argentina                                 15.2           19.500000
# Armenia                                    9.2           38.299999
# ...                                        ...                 ...
# United States                             12.9           18.700001
# Uruguay                                   15.4           20.799999
# Uzbekistan                                15.3           20.600000
# Zambia                                    34.7           26.400000
# Zimbabwe                                  28.1            9.600000
#
#                 PIB em 2010
# Country
# Afghanistan     1637.377987
# Albania         9628.025783
# Angola          6230.297028
# Argentina      18524.856760
# Armenia         6565.678660
# ...                     ...
# United States  48466.823380
# Uruguay        16808.284880
# Uzbekistan      5136.234068
# Zambia          3269.794329
# Zimbabwe        1888.566739
#
# [121 rows x 8 columns]

# %%
#Renomeando todas as colunas para deixar em português e com algumas unidades utilizadas
tabela_final = tabela_final.rename(columns={'Beef and bufallo (kilograms per year)' : 'Carne consumida/capita (kg/ano)'})
tabela_final = tabela_final.rename(columns={'HDI' : 'IDH'})
tabela_final = tabela_final.rename(columns={'Meat Tonnes' : 'Carne produzida (toneladas/ano)'})
tabela_final = tabela_final.rename(columns={'Life expectancy' : 'Expectativa de vida (anos)'})
tabela_final = tabela_final.rename(columns={'Mean years of schooling' : 'Média de escolaridade (anos)'})
tabela_final = tabela_final.rename(columns={'Coefficient of human inequality' : 'Coeficiente de desigualdade humana'})
tabela_final = tabela_final.rename(columns={'Desemprego em 2010' : 'Taxa de desemprego (%)'})
tabela_final = tabela_final.rename(columns={'PIB em 2010' : 'PIB per capita (U$)'})

# %%
tabela_final.head(50)
# Out:
#                           Carne produzida (toneladas/ano)  \
# Country
# Afghanistan                                        328160
# Albania                                             91440
# Angola                                             217027
# Argentina                                         4721922
# Armenia                                             69484
# Australia                                         4047952
# Austria                                            920059
# Azerbaijan                                         251911
# Bangladesh                                         607355
# Belarus                                            971400
# Belgium                                           1816000
# Belize                                              16600
# Benin                                               64933
# Bosnia and Herzegovina                              76250
# Botswana                                            81666
# Brazil                                           23630101
# Bulgaria                                           221004
# Burkina Faso                                       261847
# Cambodia                                           205872
# Cameroon                                           291201
# Canada                                            4440630
# Central African Republic                           157695
# Chad                                               475841
# Chile                                             1326708
# Colombia                                          2049024
# Costa Rica                                         259709
# Croatia                                            219210
# Cyprus                                              95847
# Czech Republic                                     602891
# Denmark                                           1993437
# Dominican Republic                                 460685
# Ecuador                                            805917
# El Salvador                                        145945
# Estonia                                             75420
# Ethiopia                                           749179
# Fiji                                                21587
# Finland                                            386527
# France                                            5810231
# Gabon                                               36292
# Georgia                                             56400
# Germany                                           8220492
# Ghana                                              224567
# Greece                                             454349
# Guatemala                                          352746
# Guinea                                              92064
# Guinea-Bissau                                       24335
# Guyana                                              28285
# Haiti                                              103839
# Honduras                                           205653
# Hungary                                            869810
#
#                           Carne consumida/capita (kg/ano)    IDH  \
# Country
# Afghanistan                                          4.70  0.479
# Albania                                             21.38  0.764
# Angola                                               6.67  0.533
# Argentina                                           54.65  0.827
# Armenia                                             18.01  0.743
# Australia                                           37.25  0.939
# Austria                                             17.41  0.893
# Azerbaijan                                          12.35  0.759
# Bangladesh                                           1.29  0.579
# Belarus                                             18.64  0.796
# Belgium                                             18.19  0.896
# Belize                                               4.81  0.706
# Benin                                                3.03  0.485
# Bosnia and Herzegovina                               9.10  0.750
# Botswana                                             7.37  0.698
# Brazil                                              38.69  0.754
# Bulgaria                                             4.97  0.794
# Burkina Faso                                         7.95  0.402
# Cambodia                                             5.06  0.563
# Cameroon                                             4.01  0.518
# Canada                                              29.79  0.920
# Central African Republic                            19.54  0.352
# Chad                                                 8.09  0.396
# Chile                                               21.66  0.847
# Colombia                                            16.16  0.727
# Costa Rica                                          17.75  0.776
# Croatia                                              9.19  0.827
# Cyprus                                               6.41  0.856
# Czech Republic                                       9.59  0.878
# Denmark                                             29.31  0.925
# Dominican Republic                                  11.57  0.722
# Ecuador                                             17.39  0.739
# El Salvador                                          9.23  0.680
# Estonia                                             12.63  0.865
# Ethiopia                                             4.81  0.448
# Fiji                                                 9.65  0.736
# Finland                                             18.63  0.895
# France                                              25.92  0.897
# Gabon                                                7.13  0.697
# Georgia                                              7.29  0.769
# Germany                                             12.59  0.926
# Ghana                                                1.28  0.579
# Greece                                              20.28  0.866
# Guatemala                                            5.58  0.640
# Guinea                                               5.74  0.414
# Guinea-Bissau                                        4.02  0.424
# Guyana                                               3.10  0.638
# Haiti                                                4.62  0.493
# Honduras                                             7.75  0.625
# Hungary                                              5.31  0.836
#
#                           Expectativa de vida (anos)  \
# Country
# Afghanistan                                     60.7
# Albania                                         78.0
# Angola                                          52.7
# Argentina                                       76.5
# Armenia                                         74.9
# Australia                                       82.5
# Austria                                         81.6
# Azerbaijan                                      70.9
# Bangladesh                                      72.0
# Belarus                                         71.5
# Belgium                                         81.0
# Belize                                          70.1
# Benin                                           59.8
# Bosnia and Herzegovina                          76.6
# Botswana                                        64.5
# Brazil                                          74.7
# Bulgaria                                        74.3
# Burkina Faso                                    59.0
# Cambodia                                        68.8
# Cameroon                                        56.0
# Canada                                          82.2
# Central African Republic                        51.5
# Chad                                            51.9
# Chile                                           82.0
# Colombia                                        74.2
# Costa Rica                                      79.6
# Croatia                                         77.5
# Cyprus                                          80.3
# Czech Republic                                  78.8
# Denmark                                         80.4
# Dominican Republic                              73.7
# Ecuador                                         76.1
# El Salvador                                     73.3
# Estonia                                         77.0
# Ethiopia                                        64.6
# Fiji                                            70.2
# Finland                                         81.0
# France                                          82.4
# Gabon                                           64.9
# Georgia                                         75.0
# Germany                                         81.1
# Ghana                                           61.5
# Greece                                          81.1
# Guatemala                                       72.1
# Guinea                                          59.2
# Guinea-Bissau                                   55.5
# Guyana                                          66.5
# Haiti                                           63.1
# Honduras                                        73.3
# Hungary                                         75.3
#
#                           Média de escolaridade (anos)  \
# Country
# Afghanistan                                        3.6
# Albania                                            9.6
# Angola                                             5.0
# Argentina                                          9.9
# Armenia                                           11.3
# Australia                                         13.2
# Austria                                           11.3
# Azerbaijan                                        11.2
# Bangladesh                                         5.2
# Belarus                                           12.0
# Belgium                                           11.4
# Belize                                            10.5
# Benin                                              3.5
# Bosnia and Herzegovina                             9.0
# Botswana                                           9.2
# Brazil                                             7.8
# Bulgaria                                          10.8
# Burkina Faso                                       1.4
# Cambodia                                           4.7
# Cameroon                                           6.1
# Canada                                            13.1
# Central African Republic                           4.2
# Chad                                               2.3
# Chile                                              9.9
# Colombia                                           7.6
# Costa Rica                                         8.7
# Croatia                                           11.2
# Cyprus                                            11.7
# Czech Republic                                    12.3
# Denmark                                           12.7
# Dominican Republic                                 7.7
# Ecuador                                            8.3
# El Salvador                                        6.5
# Estonia                                           12.5
# Ethiopia                                           2.6
# Fiji                                              10.5
# Finland                                           11.2
# France                                            11.6
# Gabon                                              8.1
# Georgia                                           12.2
# Germany                                           13.2
# Ghana                                              6.9
# Greece                                            10.5
# Guatemala                                          6.3
# Guinea                                             2.6
# Guinea-Bissau                                      2.9
# Guyana                                             8.4
# Haiti                                              5.2
# Honduras                                           6.2
# Hungary                                           12.0
#
#                           Coeficiente de desigualdade humana  \
# Country
# Afghanistan                                             30.4
# Albania                                                 13.4
# Angola                                                  36.6
# Argentina                                               15.2
# Armenia                                                  9.2
# Australia                                                8.0
# Austria                                                  8.5
# Azerbaijan                                              13.0
# Bangladesh                                              28.6
# Belarus                                                  6.4
# Belgium                                                  8.3
# Belize                                                  21.8
# Benin                                                   37.1
# Bosnia and Herzegovina                                  13.1
# Botswana                                                36.2
# Brazil                                                  25.0
# Bulgaria                                                10.5
# Burkina Faso                                            33.3
# Cambodia                                                22.4
# Cameroon                                                32.4
# Canada                                                   8.7
# Central African Republic                                43.1
# Chad                                                    39.6
# Chile                                                   17.1
# Colombia                                                23.7
# Costa Rica                                              18.2
# Croatia                                                  8.9
# Cyprus                                                  10.8
# Czech Republic                                           5.3
# Denmark                                                  7.0
# Dominican Republic                                      21.6
# Ecuador                                                 20.2
# El Salvador                                             22.0
# Estonia                                                  8.6
# Ethiopia                                                25.5
# Fiji                                                    15.1
# Finland                                                  5.7
# France                                                   9.3
# Gabon                                                   23.8
# Georgia                                                 12.2
# Germany                                                  7.0
# Ghana                                                   32.5
# Greece                                                  12.2
# Guatemala                                               29.1
# Guinea                                                  33.6
# Guinea-Bissau                                           39.1
# Guyana                                                  18.5
# Haiti                                                   39.2
# Honduras                                                28.5
# Hungary                                                  7.6
#
#                           Taxa de desemprego (%)  PIB per capita (U$)
# Country
# Afghanistan                            20.600000          1637.377987
# Albania                                25.799999          9628.025783
# Angola                                 10.800000          6230.297028
# Argentina                              19.500000         18524.856760
# Armenia                                38.299999          6565.678660
# Australia                              11.400000         39324.368950
# Austria                                 8.800000         42006.046880
# Azerbaijan                             14.600000         15884.044790
# Bangladesh                              8.200000          2466.902949
# Belarus                                13.200000         15927.874700
# Belgium                                22.500000         39836.897710
# Belize                                 20.900000          7555.204308
# Benin                                   2.000000          1781.563317
# Bosnia and Herzegovina                 57.200001          9347.583517
# Botswana                               33.000000         12964.351440
# Brazil                                 17.200001         14320.368690
# Bulgaria                               22.900000         14934.132740
# Burkina Faso                            5.200000          1394.253100
# Cambodia                                0.900000          2470.704155
# Cameroon                                6.400000          2817.572722
# Canada                                 14.800000         40012.391400
# Central African Republic               10.800000           962.291972
# Chad                                   10.400000          1875.557261
# Chile                                  18.600000         18161.803920
# Colombia                               24.299999         10732.749050
# Costa Rica                             17.000000         12644.696650
# Croatia                                33.500000         19761.484910
# Cyprus                                 16.000000         33421.042620
# Czech Republic                         18.500000         27667.432900
# Denmark                                14.100000         42999.616140
# Dominican Republic                     25.299999         11132.937640
# Ecuador                                11.300000          9114.338328
# El Salvador                            13.000000          6152.394745
# Estonia                                33.299999         21796.610100
# Ethiopia                                7.400000          1052.606672
# Fiji                                   20.100000          7202.758363
# Finland                                20.400000         38953.357600
# France                                 22.600000         35900.045570
# Gabon                                  34.500000         15190.414410
# Georgia                                36.799999          7145.520193
# Germany                                 9.700000         38949.549760
# Ghana                                  11.400000          2964.431120
# Greece                                 32.400002         28148.422420
# Guatemala                               5.700000          6576.668609
# Guinea                                  1.900000          1632.386304
# Guinea-Bissau                          10.700000          1401.692456
# Guyana                                 23.299999          5706.200768
# Haiti                                  19.299999          1478.736255
# Honduras                                9.100000          3832.545410
# Hungary                                26.600000         21569.890080

# %%
#Criando uma nova variável com o dataset final para facilitar
df = tabela_final[['Carne produzida (toneladas/ano)', 'Carne consumida/capita (kg/ano)',
       'IDH', 'Expectativa de vida (anos)', 'Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)',
       'PIB per capita (U$)']]

df.describe()
# Out:
#        Carne produzida (toneladas/ano)  Carne consumida/capita (kg/ano)  \
# count                     1.210000e+02                       121.000000
# mean                      1.500236e+06                        11.749174
# std                       4.511072e+06                         9.517539
# min                       8.380000e+02                         0.490000
# 25%                       9.584700e+04                         4.990000
# 50%                       2.858190e+05                         8.490000
# 75%                       9.714000e+05                        17.750000
# max                       4.195275e+07                        54.650000
#
#               IDH  Expectativa de vida (anos)  Média de escolaridade (anos)  \
# count  121.000000                  121.000000                    121.000000
# mean     0.705091                   71.523967                      8.559504
# std      0.162174                    8.735770                      3.253449
# min      0.352000                   50.100000                      1.400000
# 25%      0.563000                   65.100000                      6.100000
# 50%      0.739000                   74.200000                      9.000000
# 75%      0.843000                   78.000000                     11.300000
# max      0.949000                   83.700000                     13.400000
#
#        Coeficiente de desigualdade humana  Taxa de desemprego (%)  \
# count                          121.000000              121.000000
# mean                            19.768595               18.919835
# std                             10.302096               11.503569
# min                              5.300000                0.700000
# 25%                             10.200000               10.300000
# 50%                             18.200000               17.100000
# 75%                             28.600000               25.000000
# max                             43.100000               57.200001
#
#        PIB per capita (U$)
# count           121.000000
# mean          15462.403182
# std           15349.107505
# min             795.682826
# 25%            3269.794329
# 50%           10227.325960
# 75%           21048.330520
# max           85613.586610

# %% [markdown]
# ## Com o DataSet final (todas as informações reunidas em um único DataSet), iremos fazer algumas análises exploratórias...

# %%
# %matplotlib inline
import seaborn as sns
sns.pairplot(df, height=3);

# %% [markdown]
# ### Por meio de uma análise um pouco mais superficial, podemos concluir algumas relações:

# %% [markdown]
# - IDH: Correlação com expectativa de vida, média de escolaridade, coeficiente de desigualdade humana e PIB per capita
# - Expectativa de vida: Correlação com IDH e PIB per capita
# - Média de escolaridade: Correlação com IDH, coeficiente de desigualdade humana e PIB per capita
# - Coeficiente de desigualdade humana: Correlação com IDH, expectativa de vida, média de escolaridade e PIB per capita
# - Taxa de desemprego: Nenhuma correlação muito forte
# - PIB per capita: Correlação com IDH, expectativa de vida, média de escolaridade e coeficiente de desigualdade humana

# %% [markdown]
# ### Para que essas conclusões tenham mais embasamento, vamos ver alguns casos específicos para que possam ser estabelecidas análises mais precisas.

# %%
sns.set_theme(color_codes=True)
fig_expect = sns.scatterplot(data=df, x='Expectativa de vida (anos)', y='Carne produzida (toneladas/ano)', hue='PIB per capita (U$)')
plt.show(fig_expect)

# %% [markdown]
# #### A partir do gráfico, pode-se notar que o PIB per capita dos países está diretamente relacionado com a expectativa de vida, tendo em vista que a medida que o eixo X (expectativa de vida) cresce, mais bolinhas escuras são observadas (quanto mais escura, maior o PIB per capita). Em relação à carne produzida, não se pode tirar muitas conclusões, apesar de que observa-se que à medida que a expectativa de vida cresce, mais pontos são observados em uma posição maior em relação ao eixo Y (carne produzida). Com isso, tira-se a conclusão de que eles podem até estar relacionados, porém essa relação acaba não sendo tão forte/visível.

# %%
graf_linha_expec = sns.lineplot(data=df, x='Expectativa de vida (anos)', y='Carne produzida (toneladas/ano)')
plt.show(graf_linha_expec)

# %% [markdown]
# #### Conforeme há um aumento na expectativa de vida (eixo X cresce), valores maiores de carne produzida podem ser observados. Entretanto, esses valores não apresentam um alto grau de constância, tendo em vista que são identificados apenas alguns picos, porém muitos valores (no eixo X) em uma mesma faixa de carne produzida (no eixo Y).

# %%
sns.set_theme(color_codes=True)
fig_pib = sns.scatterplot(data=df, x='PIB per capita (U$)', y='Carne produzida (toneladas/ano)', hue='Média de escolaridade (anos)')
plt.show(fig_pib)

# %% [markdown]
# #### Com base no gráfico obtido, nota-se um alto grau de relação entre a média de escolaridade e o PIB per capita, tendo em vista que à medida que o eixo X cresce (maior PIB), mais bolinhas escuras (maior escolaridade) são observadas. No entanto, não se pode observar um grau de relação muito grande entre essas duas variáveis e a carne produzida, tendo em vista que a maior parte dos valores estão na mesma faixa abaixo de 1 tonelada de carne produzida, independente do número do PIB do país.

# %%
hist_pib = sns.displot(data=df, x='PIB per capita (U$)', y='Carne produzida (toneladas/ano)', kind='kde', rug='True')
plt.show(hist_pib)

# %% [markdown]
# #### Com o gráfico obtido, nota-se um pouco da desigualdade econômica entre os países analisados no projeto, tendo em vista que a maior parte dos países analisados possuem um PIB per capita menor que 40000 dólares. Apesar dessa desigualdade, nota-se que a maior parte desses países não apresentam uma grande diferença no que diz respeito à carne produzida, evidênciando que as duas variáveis não apresentam um alto grau de relação.

# %%
sns.set_theme(color_codes=True)
fig_esc = sns.scatterplot(data=df, x='Média de escolaridade (anos)', y='Carne produzida (toneladas/ano)', hue='Coeficiente de desigualdade humana')
plt.show(fig_esc)

# %% [markdown]
# #### Neste gráfico nota-se o alto grau de relação (inversamente proporcionais) entre a média de escolaridade e o coeficiente de desigualdade humana, tendo em vista que à medida que o eixo X (média de escolaridade) cresce, mais bolinhas brancas (menor coeficiente de desigualdade) são observadas. Apesar disso, é possivel observar que nenhuma das variáveis tem uma significante relação com a carne produzida. Isso, pois alguns pontos de escolaridade são observados num maior nível de carne produzida, porém essa diferença é muito inconstante e não é muito significativa.

# %%
fig_consum = sns.scatterplot(data=df, x='Carne consumida/capita (kg/ano)', y='Carne produzida (toneladas/ano)', hue='Taxa de desemprego (%)')
plt.show(fig_consum)

# %% [markdown]
# #### Com o gráfico, nota-se que a taxa de desemprego não apresenta nenhum grau de relação aparente com a carne consumida, tendo em vista que a cor das bolinhas não apresenta nenhum padrão à medida que o eixo X (carne consumida) cresce. Apesar disso, é evidente que os países com maior carne produzida estão localizados à direita do gráfico (mostrando que os países com maior consumo de carne são os mesmos que apresentam maior produção dela.

# %% [markdown]
# ## Regressões

# %%
#Criando uma função que sirva para criar as regressões que vamos utilizar para analisar o projeto
def regress(Y,X):
    '''
    Y: coluna do DataFrame utilizada como variável resposta (TARGET)
    X: coluna(s) do DataFrame utilizadas como variável(is) explicativas (FEATURES)
    '''
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    
    return results

# %%
#Separando em 'target' e 'feature' para fazer a regressão
X1 = df[['Carne consumida/capita (kg/ano)',
       'IDH', 'Expectativa de vida (anos)', 'Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)',
       'PIB per capita (U$)']]
Y1 = df['Carne produzida (toneladas/ano)']

# %% [markdown]
# ### Primeira regressão.

# %% [markdown]
# ### Segunda regressão - agora iremos retirar a expectativa de vida do dataset e refazer a regressão para analisar outra feature, que no caso será o PIB per capta (maior P>|t|).

# %%
#Separando em 'target' e 'feature' para fazer a regressão
X2 = df[['Carne consumida/capita (kg/ano)',
       'IDH','Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)',
       'PIB per capita (U$)']]
Y2 = df['Carne produzida (toneladas/ano)']

# %% [markdown]
# ### Terceira regressão - agora iremos retirar o PIB per capita do dataset e refazer a regressão para analisar outra feature, que no caso será a média de escolaridade (maior P>|t|).

# %%
#Separando em 'target' e 'feature' para fazer a regressão
X3 = df[['Carne consumida/capita (kg/ano)',
       'IDH','Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)']]
Y3 = df['Carne produzida (toneladas/ano)']

# %%
#Fazendo a regressão
results3 = regress(Y3,X3)
results3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     Carne produzida (toneladas/ano)   R-squared:                       0.221
# Model:                                         OLS   Adj. R-squared:                  0.187
# Method:                              Least Squares   F-statistic:                     6.515
# Date:                             Tue, 30 Nov 2021   Prob (F-statistic):           2.27e-05
# Time:                                     23:00:05   Log-Likelihood:                -2010.1
# No. Observations:                              121   AIC:                             4032.
# Df Residuals:                                  115   BIC:                             4049.
# Df Model:                                        5
# Covariance Type:                         nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                              -1.052e+07   5.45e+06     -1.929      0.056   -2.13e+07     2.8e+05
# Carne consumida/capita (kg/ano)      1.97e+05   4.85e+04      4.065      0.000    1.01e+05    2.93e+05
# IDH                                 8.065e+06   7.47e+06      1.080      0.282   -6.72e+06    2.29e+07
# Média de escolaridade (anos)        1.131e+05   3.28e+05      0.345      0.731   -5.37e+05    7.63e+05
# Coeficiente de desigualdade humana  1.728e+05   8.84e+04      1.955      0.053   -2268.768    3.48e+05
# Taxa de desemprego (%)             -1.944e+04   3.44e+04     -0.566      0.573   -8.75e+04    4.86e+04
# ==============================================================================
# Omnibus:                      179.465   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10548.064
# Skew:                           5.704   Prob(JB):                         0.00
# Kurtosis:                      47.295   Cond. No.                         756.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Quarta regressão - agora iremos retirar a média de escolaridade e a taxa de desemprego (maiores P>|t|).

# %%
#Separando em 'target' e 'feature' para fazer a regressão
X4 = df[['Carne consumida/capita (kg/ano)','Coeficiente de desigualdade humana']]
Y4 = df['Carne produzida (toneladas/ano)']

# %%
#Fazendo a regressão
results4 = regress(Y4,X4)
results4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     Carne produzida (toneladas/ano)   R-squared:                       0.202
# Model:                                         OLS   Adj. R-squared:                  0.188
# Method:                              Least Squares   F-statistic:                     14.90
# Date:                             Tue, 30 Nov 2021   Prob (F-statistic):           1.70e-06
# Time:                                     23:00:06   Log-Likelihood:                -2011.5
# No. Observations:                              121   AIC:                             4029.
# Df Residuals:                                  118   BIC:                             4037.
# Df Model:                                        2
# Covariance Type:                         nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                              -2.112e+06   1.19e+06     -1.777      0.078   -4.47e+06    2.42e+05
# Carne consumida/capita (kg/ano)     2.307e+05   4.38e+04      5.271      0.000    1.44e+05    3.17e+05
# Coeficiente de desigualdade humana  4.565e+04   4.04e+04      1.129      0.261   -3.44e+04    1.26e+05
# ==============================================================================
# Omnibus:                      180.337   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10723.822
# Skew:                           5.750   Prob(JB):                         0.00
# Kurtosis:                      47.663   Cond. No.                         78.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# %matplotlib notebook

# Recupera os parâmetros calculados
beta0_hat = results4.params[0]  # const
beta1_hat = results4.params[1]  # consumo
beta2_hat = results4.params[2]  # coef desiguald

# Define uma função que aplica aos parâmetros
def f(feature1, feature2):
    return beta0_hat + beta1_hat*feature1 + beta2_hat*feature2

# Gera 100 pontos entre os menores e maiores valores de cada feature
npoints = 100
feature1 = X4['Carne consumida/capita (kg/ano)']
feature2= X4['Coeficiente de desigualdade humana']
x_vc = np.linspace(feature1.min(), feature1.max(), npoints)
y_vc = np.linspace(feature2.min(), feature2.max(), npoints)

y_vc = np.linspace(feature2.min(), feature2.max(), npoints)


# Constrói uma grade de 100x100 pontos 
eixo_x, eixo_y = np.meshgrid(x_vc, y_vc)

# Aplica a função em cada ponto da grade 
# Constrói plano estimado
fit_z = f(eixo_x, eixo_y)

# Plota os pontos e o plano em 3D
plt3d = plt.figure().gca(projection="3d")
plt3d.plot_surface(eixo_x, eixo_y, fit_z)
plt3d.scatter(feature1, feature2, Y4, color="r")
plt3d.set_xlabel("feature1")
plt3d.set_ylabel("feature2")
plt3d.set_zlabel("Y")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="540">

# %% [markdown]
# ### Com isso, notam-se as principais variáveis que estão relacionadas com a produção de carne, sendo elas o IDH, o coeficiente de desigualdade humana e a carne consumida. Essa conclusão pode ser tomada com base no P>|t| extremamente baixo dessas variáveis, ou seja, possuem baixo grau de relevância para a análise.

# %%
#Criando uma nova variável com o dataset final para facilitar
df = tabela_final[['Carne produzida (toneladas/ano)', 'Carne consumida/capita (kg/ano)',
       'IDH', 'Expectativa de vida (anos)', 'Média de escolaridade (anos)',
       'Coeficiente de desigualdade humana', 'Taxa de desemprego (%)',
       'PIB per capita (U$)']]

# %% [markdown]
# ### Separando nosso modelo em treino e teste para maior precisão do projeto, utilizamos da Regression Tree, sendo assim:

# %%
data = df.values
X, y = data[:, :-1], data[:, -1]
print(X.shape, y.shape)
# separar em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# fit no modelo
model = RandomForestRegressor(random_state=1)
model.fit(X_train, y_train)
# fazer previsão
yhat = model.predict(X_test)
# avaliar previsão
mae = mean_absolute_error(y_test, yhat)
print('mean absolute error: %.3f' % mae)
# Out:
# (121, 7) (121,)
# (81, 7) (40, 7) (81,) (40,)
# mean absolute error: 3733.559

# %%
dtregression = DecisionTreeRegressor(random_state=0)
scores = cross_val_score(dtregression, X_train, y_train, cv=10)
print ('{0} de acurácia de um desvio padrão de {1} - treino' .format(scores.mean(), scores.std()))
# Out:
# 0.7492192881766206 de acurácia de um desvio padrão de 0.17198950671347704 - treino

# %%
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(df, df['Carne produzida (toneladas/ano)'])
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = regressor.predict(df)
print ('Acurácia: ',accuracy_score(df['Carne produzida (toneladas/ano)'], y_pred))
# Out:
# Acurácia:  1.0

# %%
final_regres = DecisionTreeRegressor(random_state=0)
final_regres.fit(X_train, y_train)
a = final_regres.score(X_test, y_test)
print ('{0} de acurácia - teste' .format(a))
# Out:
# 0.6236906750370189 de acurácia - teste

# %% [markdown]
# #### Com os dados apresentados anteriormente, concluimos que:

# %% [markdown]
# - A acurácia do treino (74%) é maior do que as do teste (62%), sendo assim um bom sinal que comprova a efetividade do sistema
# - A média absoluta do erro é de 37,3% da média dos valores analisados, sendo assim relativamente baixa e efetivando o nosso sistema.
# - Nosso sistema é coerente e efetivo para respondermos à pergunta inicial em relação à produção de carne de um país, segundo determinadas informações que são disponibilizadas
